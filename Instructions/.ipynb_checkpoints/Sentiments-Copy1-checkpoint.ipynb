# %%
#dependencies
import tweepy
import pandas as pd
import numpy as np
import json
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime, timezone
from config import  consumer_key, consumer_secret, access_token, access_token_secret

# %%
#import vader for sentiment analysis
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
#autheticate#autheti 
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
#make dictionary of twitter SNs, network names, and colors for graphs
news_labels = ["@CNN", "@BBCWorld", "@CBSNews", "@nytimes", "@FoxNews"]
colors = ['red', 'blue','lightblue', 'green', 'yellow']

# %%
#create empty dictionary for data returned from json dump
news_dict = {
    "Screen Name": [],
    "Tweet": [],
    "Date": [],
    "Compound Score": [],
    "Positive Score": [],
    "Negative Score": [],
    "Neutral Score": [],
    "Tweets Ago": []
}

# %%
# Print out one news label to get example json 
oldest_tweet = None

target_user = "BBCWorld"
public_tweets = api.user_timeline(target_user, count=100, result_type="recent", max_id=oldest_tweet)
# print(public_tweets) 
print(json.dumps(public_tweets, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Sat Jun 09 00:33:12 +0000 2018",
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [
#                 {
#                     "display_url": "bbc.in/2JlyzA8",
#                     "expanded_url": "https://bbc.in/2JlyzA8",
#                     "indices": [
#                         57,
#                         80
#                     ],
#                     "url": "https://t.co/lrP0LJKC7n"
#                 }
#             ],
#             "user_mentions": []
#         },
#         "favorite_count": 416,
#         "favorited": false,
#         "geo": null,
#         "id": 1005246399661924352,
#         "id_str": "1005246399661924352",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "en",
#         "place": null,
#         "possibly_sensitive": false,
#         "retweet_count": 132,
#         "retweeted": false,
#         "source": "<a href=\"http://www.socialflow.com\" rel=\"nofollow\">SocialFlow</a>",
#         "text": "Anthony Bourdain: Why his travel shows had global appeal https://t.co/lrP0LJKC7n",
#         "truncated": false,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Thu Feb 01 07:44:29 +0000 2007",
#             "default_profile": false,
#             "default_profile_image": false,
#             "description": "News, features and analysis from the World's newsroom. Breaking news, follow @BBCBreaking. UK news, @BBCNews. Latest sports news @BBCSport",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "display_url": "bbc.com/news",
#                             "expanded_url": "http://www.bbc.com/news",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "url": "https://t.co/7NEgoMwJy3"
#                         }
#                     ]
#                 }
#             },
#             "favourites_count": 9,
#             "follow_request_sent": false,
#             "followers_count": 23513583,
#             "following": false,
#             "friends_count": 85,
#             "geo_enabled": false,
#             "has_extended_profile": false,
#             "id": 742143,
#             "id_str": "742143",
#             "is_translation_enabled": true,
#             "is_translator": false,
#             "lang": "en",
#             "listed_count": 108988,
#             "location": "London, UK",
#             "name": "BBC News (World)",
#             "notifications": false,
#             "profile_background_color": "FFFFFF",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/742143/1485172490",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/875702138680246273/BfQLzf7G_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/875702138680246273/BfQLzf7G_normal.jpg",
#             "profile_link_color": "1F527B",
#             "profile_sidebar_border_color": "FFFFFF",
#             "profile_sidebar_fill_color": "FFFFFF",
#             "profile_text_color": "5A5A5A",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "BBCWorld",
#             "statuses_count": 279279,
#             "time_zone": null,
#             "translator_type": "none",
#             "url": "https://t.co/7NEgoMwJy3",
#             "utc_offset": null,
#             "verified": true
#         }
#     },
#     {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Fri Jun 08 23:10:00 +0000 2018",
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [
#                 {
#                     "display_url": "bbc.in/2xUhesR",
#                     "expanded_url": "https://bbc.in/2xUhesR",
#                     "indices": [
#                         59,
#                         82
#                     ],
#                     "url": "https://t.co/A0UxMnLFFj"
#                 }
#             ],
#             "user_mentions": []
#         },
#         "favorite_count": 173,
#         "favorited": false,
#         "geo": null,
#         "id": 1005225459267883010,
#         "id_str": "1005225459267883010",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "en",
#         "place": null,
#         "possibly_sensitive": false,
#         "retweet_count": 175,
#         "retweeted": false,
#         "source": "<a href=\"http://www.socialflow.com\" rel=\"nofollow\">SocialFlow</a>",
#         "text": "China hackers steal data from US Navy contractor - reports https://t.co/A0UxMnLFFj",
#         "truncated": false,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Thu Feb 01 07:44:29 +0000 2007",
#             "default_profile": false,
#             "default_profile_image": false,
#             "description": "News, features and analysis from the World's newsroom. Breaking news, follow @BBCBreaking. UK news, @BBCNews. Latest sports news @BBCSport",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "display_url": "bbc.com/news",
#                             "expanded_url": "http://www.bbc.com/news",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "url": "https://t.co/7NEgoMwJy3"
#                         }
#                     ]
#                 }
#             },
#             "favourites_count": 9,
#             "follow_request_sent": false,
#             "followers_count": 23513583,
#             "following": false,
#             "friends_count": 85,
#             "geo_enabled": false,
#             "has_extended_profile": false,
#             "id": 742143,
#             "id_str": "742143",
#             "is_translation_enabled": true,
#             "is_translator": false,
#             "lang": "en",
#             "listed_count": 108988,
#             "location": "London, UK",
#             "name": "BBC News (World)",
#             "notifications": false,
#             "profile_background_color": "FFFFFF",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/742143/1485172490",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/875702138680246273/BfQLzf7G_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/875702138680246273/BfQLzf7G_normal.jpg",
#             "profile_link_color": "1F527B",
#             "profile_sidebar_border_color": "FFFFFF",
#             "profile_sidebar_fill_color": "FFFFFF",
#             "profile_text_color": "5A5A5A",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "BBCWorld",
#             "statuses_count": 279279,
#             "time_zone": null,
#             "translator_type": "none",
#             "url": "https://t.co/7NEgoMwJy3",
#             "utc_offset": null,
#             "verified": true
#         }
#     },
#     {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Fri Jun 08 23:10:00 +0000 2018",
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [
#                 {
#                     "display_url": "bbc.in/2JmnXB7",
#                     "expanded_url": "https://bbc.in/2JmnXB7",
#                     "indices": [
#                         50,
#                         73
#                     ],
#                     "url": "https://t.co/K2vn2PyLt3"
#                 }
#             ],
#             "user_mentions": []
#         },
#         "favorite_count": 102,
#         "favorited": false,
#         "geo": null,
#         "id": 1005225459108458497,
#         "id_str": "1005225459108458497",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "en",
#         "place": null,
#         "possibly_sensitive": false,
#         "retweet_count": 52,
#         "retweeted": false,
#         "source": "<a href=\"http://www.socialflow.com\" rel=\"nofollow\">SocialFlow</a>",
#         "text": "Why Russian workers are being taught how to smile https://t.co/K2vn2PyLt3",
#         "truncated": false,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Thu Feb 01 07:44:29 +0000 2007",
#             "default_profile": false,
#             "default_profile_image": false,
#             "description": "News, features and analysis from the World's newsroom. Breaking news, follow @BBCBreaking. UK news, @BBCNews. Latest sports news @BBCSport",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "display_url": "bbc.com/news",
#                             "expanded_url": "http://www.bbc.com/news",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "url": "https://t.co/7NEgoMwJy3"
#                         }
#                     ]
#                 }
#             },
#             "favourites_count": 9,
#             "follow_request_sent": false,
#             "followers_count": 23513583,
#             "following": false,
#             "friends_count": 85,
#             "geo_enabled": false,
#             "has_extended_profile": false,
#             "id": 742143,
#             "id_str": "742143",
#             "is_translation_enabled": true,
#             "is_translator": false,
#             "lang": "en",
#             "listed_count": 108988,
#             "location": "London, UK",
#             "name": "BBC News (World)",
#             "notifications": false,
#             "profile_background_color": "FFFFFF",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/742143/1485172490",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/875702138680246273/BfQLzf7G_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/875702138680246273/BfQLzf7G_normal.jpg",
#             "profile_link_color": "1F527B",
#             "profile_sidebar_border_color": "FFFFFF",
#             "profile_sidebar_fill_color": "FFFFFF",
#             "profile_text_color": "5A5A5A",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "BBCWorld",
#             "statuses_count": 279279,
#             "time_zone": null,
#             "translator_type": "none",
#             "url": "https://t.co/7NEgoMwJy3",
#             "utc_offset": null,
#             "verified": true
#         }
#     },
#     {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Fri Jun 08 23:10:00 +0000 2018",
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [
#                 {
#                     "display_url": "bbc.in/2Jn3Y5d",
#                     "expanded_url": "https://bbc.in/2Jn3Y5d",
#                     "indices": [
#                         38,
#                         61
#                     ],
#                     "url": "https://t.co/uqG5k3pvIF"
#                 }
#             ],
#             "user_mentions": []
#         },
#         "favorite_count": 36,
#         "favorited": false,
#         "geo": null,
#         "id": 1005225459091759105,
#         "id_str": "1005225459091759105",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "en",
#         "place": null,
#         "possibly_sensitive": false,
#         "retweet_count": 19,
#         "retweeted": false,
#         "source": "<a href=\"http://www.socialflow.com\" rel=\"nofollow\">SocialFlow</a>",
#         "text": "'They keep me here so I can't attack' https://t.co/uqG5k3pvIF",
#         "truncated": false,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Thu Feb 01 07:44:29 +0000 2007",
#             "default_profile": false,
#             "default_profile_image": false,
#             "description": "News, features and analysis from the World's newsroom. Breaking news, follow @BBCBreaking. UK news, @BBCNews. Latest sports news @BBCSport",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "display_url": "bbc.com/news",
#                             "expanded_url": "http://www.bbc.com/news",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "url": "https://t.co/7NEgoMwJy3"
#                         }
#                     ]
#                 }
#             },
#             "favourites_count": 9,
#             "follow_request_sent": false,
#             "followers_count": 23513583,
#             "following": false,
#             "friends_count": 85,
#             "geo_enabled": false,
#             "has_extended_profile": false,
#             "id": 742143,
#             "id_str": "742143",
#             "is_translation_enabled": true,
#             "is_translator": false,
#             "lang": "en",
#             "listed_count": 108988,
#             "location": "London, UK",
#             "name": "BBC News (World)",
#             "notifications": false,
#             "profile_background_color": "FFFFFF",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/742143/1485172490",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/875702138680246273/BfQLzf7G_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/875702138680246273/BfQLzf7G_normal.jpg",
#             "profile_link_color": "1F527B",
#             "profile_sidebar_border_color": "FFFFFF",
#             "profile_sidebar_fill_color": "FFFFFF",
#             "profile_text_color": "5A5A5A",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "BBCWorld",
#             "statuses_count": 279279,
#             "time_zone": null,
#             "translator_type": "none",
#             "url": "https://t.co/7NEgoMwJy3",
#             "utc_offset": null,
#             "verified": true
#         }
#     },
#     {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Fri Jun 08 23:10:00 +0000 2018",
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [
#                 {
#                     "display_url": "bbc.in/2LxK44a",
#                     "expanded_url": "https://bbc.in/2LxK44a",
#                     "indices": [
#                         64,
#                         87
#                     ],
#                     "url": "https://t.co/Vjgk1HoL9H"
#                 }
#             ],
#             "user_mentions": []
#         },
#         "favorite_count": 55,
#         "favorited": false,
#         "geo": null,
#         "id": 1005225459091693568,
#         "id_str": "1005225459091693568",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "en",
#         "place": null,
#         "possibly_sensitive": false,
#         "retweet_count": 22,
#         "retweeted": false,
#         "source": "<a href=\"http://www.socialflow.com\" rel=\"nofollow\">SocialFlow</a>",
#         "text": "Barbed wire and smuggled crabs: Watching North Korea from China https://t.co/Vjgk1HoL9H",
#         "truncated": false,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Thu Feb 01 07:44:29 +0000 2007",
#             "default_profile": false,
#             "default_profile_image": false,
#             "description": "News, features and analysis from the World's newsroom. Breaking news, follow @BBCBreaking. UK news, @BBCNews. Latest sports news @BBCSport",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "display_url": "bbc.com/news",
#                             "expanded_url": "http://www.bbc.com/news",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "url": "https://t.co/7NEgoMwJy3"
#                         }
#                     ]
#                 }
#             },
#             "favourites_count": 9,
#             "follow_request_sent": false,
#             "followers_count": 23513583,
#             "following": false,
#             "friends_count": 85,
#             "geo_enabled": false,
#             "has_extended_profile": false,
#             "id": 742143,
#             "id_str": "742143",
#             "is_translation_enabled": true,
#             "is_translator": false,
#             "lang": "en",
#             "listed_count": 108988,
#             "location": "London, UK",
#             "name": "BBC News (World)",
#             "notifications": false,
#             "profile_background_color": "FFFFFF",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/742143/1485172490",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/875702138680246273/BfQLzf7G_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/875702138680246273/BfQLzf7G_normal.jpg",
#             "profile_link_color": "1F527B",
#             "profile_sidebar_border_color": "FFFFFF",
#             "profile_sidebar_fill_color": "FFFFFF",
#             "profile_text_color": "5A5A5A",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "BBCWorld",
#             "statuses_count": 279279,
#             "time_zone": null,
#             "translator_type": "none",
#             "url": "https://t.co/7NEgoMwJy3",
#             "utc_offset": null,
#             "verified": true
#         }
#     },
#     {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Fri Jun 08 22:27:18 +0000 2018",
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [
#                 {
#                     "display_url": "bbc.in/2xTedZZ",
#                     "expanded_url": "https://bbc.in/2xTedZZ",
#                     "indices": [
#                         35,
#                         58
#                     ],
#                     "url": "https://t.co/6jqRzwhm8Q"
#                 }
#             ],
#             "user_mentions": []
#         },
#         "favorite_count": 505,
#         "favorited": false,
#         "geo": null,
#         "id": 1005214715633700869,
#         "id_str": "1005214715633700869",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "en",
#         "place": null,
#         "possibly_sensitive": false,
#         "retweet_count": 319,
#         "retweeted": false,
#         "source": "<a href=\"http://www.socialflow.com\" rel=\"nofollow\">SocialFlow</a>",
#         "text": "Why US suicide rate is on the rise https://t.co/6jqRzwhm8Q",
#         "truncated": false,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Thu Feb 01 07:44:29 +0000 2007",
#             "default_profile": false,
#             "default_profile_image": false,
#             "description": "News, features and analysis from the World's newsroom. Breaking news, follow @BBCBreaking. UK news, @BBCNews. Latest sports news @BBCSport",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "display_url": "bbc.com/news",
#                             "expanded_url": "http://www.bbc.com/news",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "url": "https://t.co/7NEgoMwJy3"
#                         }
#                     ]
#                 }
#             },
#             "favourites_count": 9,
#             "follow_request_sent": false,
#             "followers_count": 23513583,
#             "following": false,
#             "friends_count": 85,
#             "geo_enabled": false,
#             "has_extended_profile": false,
#             "id": 742143,
#             "id_str": "742143",
#             "is_translation_enabled": true,
#             "is_translator": false,
#             "lang": "en",
#             "listed_count": 108988,
#             "location": "London, UK",
#             "name": "BBC News (World)",
#             "notifications": false,
#             "profile_background_color": "FFFFFF",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/742143/1485172490",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/875702138680246273/BfQLzf7G_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/875702138680246273/BfQLzf7G_normal.jpg",
#             "profile_link_color": "1F527B",
#             "profile_sidebar_border_color": "FFFFFF",
#             "profile_sidebar_fill_color": "FFFFFF",
#             "profile_text_color": "5A5A5A",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "BBCWorld",
#             "statuses_count": 279279,
#             "time_zone": null,
#             "translator_type": "none",
#             "url": "https://t.co/7NEgoMwJy3",
#             "utc_offset": null,
#             "verified": true
#         }
#     },
#     {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Fri Jun 08 21:49:36 +0000 2018",
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [
#                 {
#                     "display_url": "bbc.in/2xVfYG5",
#                     "expanded_url": "https://bbc.in/2xVfYG5",
#                     "indices": [
#                         54,
#                         77
#                     ],
#                     "url": "https://t.co/LOGxNymdY4"
#                 }
#             ],
#             "user_mentions": []
#         },
#         "favorite_count": 260,
#         "favorited": false,
#         "geo": null,
#         "id": 1005205226473775104,
#         "id_str": "1005205226473775104",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "en",
#         "place": null,
#         "possibly_sensitive": false,
#         "retweet_count": 64,
#         "retweeted": false,
#         "source": "<a href=\"http://www.socialflow.com\" rel=\"nofollow\">SocialFlow</a>",
#         "text": "US election 2018: The women lining up to topple Trump https://t.co/LOGxNymdY4",
#         "truncated": false,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Thu Feb 01 07:44:29 +0000 2007",
#             "default_profile": false,
#             "default_profile_image": false,
#             "description": "News, features and analysis from the World's newsroom. Breaking news, follow @BBCBreaking. UK news, @BBCNews. Latest sports news @BBCSport",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "display_url": "bbc.com/news",
#                             "expanded_url": "http://www.bbc.com/news",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "url": "https://t.co/7NEgoMwJy3"
#                         }
#                     ]
#                 }
#             },
#             "favourites_count": 9,
#             "follow_request_sent": false,
#             "followers_count": 23513583,
#             "following": false,
#             "friends_count": 85,
#             "geo_enabled": false,
#             "has_extended_profile": false,
#             "id": 742143,
#             "id_str": "742143",
#             "is_translation_enabled": true,
#             "is_translator": false,
#             "lang": "en",
#             "listed_count": 108988,
#             "location": "London, UK",
#             "name": "BBC News (World)",
#             "notifications": false,
#             "profile_background_color": "FFFFFF",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/742143/1485172490",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/875702138680246273/BfQLzf7G_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/875702138680246273/BfQLzf7G_normal.jpg",
#             "profile_link_color": "1F527B",
#             "profile_sidebar_border_color": "FFFFFF",
#             "profile_sidebar_fill_color": "FFFFFF",
#             "profile_text_color": "5A5A5A",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "BBCWorld",
#             "statuses_count": 279279,
#             "time_zone": null,
#             "translator_type": "none",
#             "url": "https://t.co/7NEgoMwJy3",
#             "utc_offset": null,
#             "verified": true
#         }
#     },
#     {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Fri Jun 08 21:49:36 +0000 2018",
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [
#                 {
#                     "display_url": "bbc.in/2sJip9v",
#                     "expanded_url": "https://bbc.in/2sJip9v",
#                     "indices": [
#                         38,
#                         61
#                     ],
#                     "url": "https://t.co/G0i7WJ60Kp"
#                 }
#             ],
#             "user_mentions": []
#         },
#         "favorite_count": 524,
#         "favorited": false,
#         "geo": null,
#         "id": 1005205226129903616,
#         "id_str": "1005205226129903616",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "en",
#         "place": null,
#         "possibly_sensitive": false,
#         "retweet_count": 203,
#         "retweeted": false,
#         "source": "<a href=\"http://www.socialflow.com\" rel=\"nofollow\">SocialFlow</a>",
#         "text": "'Kim and Trump' buddy up in Singapore https://t.co/G0i7WJ60Kp",
#         "truncated": false,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Thu Feb 01 07:44:29 +0000 2007",
#             "default_profile": false,
#             "default_profile_image": false,
#             "description": "News, features and analysis from the World's newsroom. Breaking news, follow @BBCBreaking. UK news, @BBCNews. Latest sports news @BBCSport",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "display_url": "bbc.com/news",
#                             "expanded_url": "http://www.bbc.com/news",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "url": "https://t.co/7NEgoMwJy3"
#                         }
#                     ]
#                 }
#             },
#             "favourites_count": 9,
#             "follow_request_sent": false,
#             "followers_count": 23513583,
#             "following": false,
#             "friends_count": 85,
#             "geo_enabled": false,
#             "has_extended_profile": false,
#             "id": 742143,
#             "id_str": "742143",
#             "is_translation_enabled": true,
#             "is_translator": false,
#             "lang": "en",
#             "listed_count": 108988,
#             "location": "London, UK",
#             "name": "BBC News (World)",
#             "notifications": false,
#             "profile_background_color": "FFFFFF",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/742143/1485172490",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/875702138680246273/BfQLzf7G_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/875702138680246273/BfQLzf7G_normal.jpg",
#             "profile_link_color": "1F527B",
#             "profile_sidebar_border_color": "FFFFFF",
#             "profile_sidebar_fill_color": "FFFFFF",
#             "profile_text_color": "5A5A5A",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "BBCWorld",
#             "statuses_count": 279279,
#             "time_zone": null,
#             "translator_type": "none",
#             "url": "https://t.co/7NEgoMwJy3",
#             "utc_offset": null,
#             "verified": true
#         }
#     },
#     {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Fri Jun 08 20:26:04 +0000 2018",
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [
#                 {
#                     "display_url": "bbc.in/2sGGM7O",
#                     "expanded_url": "https://bbc.in/2sGGM7O",
#                     "indices": [
#                         60,
#                         83
#                     ],
#                     "url": "https://t.co/rUEbx6eGMs"
#                 }
#             ],
#             "user_mentions": []
#         },
#         "favorite_count": 94,
#         "favorited": false,
#         "geo": null,
#         "id": 1005184203196174343,
#         "id_str": "1005184203196174343",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "en",
#         "place": null,
#         "possibly_sensitive": false,
#         "retweet_count": 51,
#         "retweeted": false,
#         "source": "<a href=\"http://www.socialflow.com\" rel=\"nofollow\">SocialFlow</a>",
#         "text": "Cuba 'sonic attack': US tests two more Havana embassy staff https://t.co/rUEbx6eGMs",
#         "truncated": false,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Thu Feb 01 07:44:29 +0000 2007",
#             "default_profile": false,
#             "default_profile_image": false,
#             "description": "News, features and analysis from the World's newsroom. Breaking news, follow @BBCBreaking. UK news, @BBCNews. Latest sports news @BBCSport",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "display_url": "bbc.com/news",
#                             "expanded_url": "http://www.bbc.com/news",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "url": "https://t.co/7NEgoMwJy3"
#                         }
#                     ]
#                 }
#             },
#             "favourites_count": 9,
#             "follow_request_sent": false,
#             "followers_count": 23513583,
#             "following": false,
#             "friends_count": 85,
#             "geo_enabled": false,
#             "has_extended_profile": false,
#             "id": 742143,
#             "id_str": "742143",
#             "is_translation_enabled": true,
#             "is_translator": false,
#             "lang": "en",
#             "listed_count": 108988,
#             "location": "London, UK",
#             "name": "BBC News (World)",
#             "notifications": false,
#             "profile_background_color": "FFFFFF",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/742143/1485172490",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/875702138680246273/BfQLzf7G_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/875702138680246273/BfQLzf7G_normal.jpg",
#             "profile_link_color": "1F527B",
#             "profile_sidebar_border_color": "FFFFFF",
#             "profile_sidebar_fill_color": "FFFFFF",
#             "profile_text_color": "5A5A5A",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "BBCWorld",
#             "statuses_count": 279279,
#             "time_zone": null,
#             "translator_type": "none",
#             "url": "https://t.co/7NEgoMwJy3",
#             "utc_offset": null,
#             "verified": true
#         }
#     },
#     {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Fri Jun 08 20:02:34 +0000 2018",
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [
#                 {
#                     "display_url": "bbc.in/2sH7oWm",
#                     "expanded_url": "https://bbc.in/2sH7oWm",
#                     "indices": [
#                         39,
#                         62
#                     ],
#                     "url": "https://t.co/rEudHbzFIX"
#                 }
#             ],
#             "user_mentions": []
#         },
#         "favorite_count": 103,
#         "favorited": false,
#         "geo": null,
#         "id": 1005178289734979589,
#         "id_str": "1005178289734979589",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "en",
#         "place": null,
#         "possibly_sensitive": false,
#         "retweet_count": 82,
#         "retweeted": false,
#         "source": "<a href=\"http://www.socialflow.com\" rel=\"nofollow\">SocialFlow</a>",
#         "text": "US soldier killed in Somalia firefight https://t.co/rEudHbzFIX",
#         "truncated": false,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Thu Feb 01 07:44:29 +0000 2007",
#             "default_profile": false,
#             "default_profile_image": false,
#             "description": "News, features and analysis from the World's newsroom. Breaking news, follow @BBCBreaking. UK news, @BBCNews. Latest sports news @BBCSport",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "display_url": "bbc.com/news",
#                             "expanded_url": "http://www.bbc.com/news",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "url": "https://t.co/7NEgoMwJy3"
#                         }
#                     ]
#                 }
#             },
#             "favourites_count": 9,
#             "follow_request_sent": false,
#             "followers_count": 23513583,
#             "following": false,
#             "friends_count": 85,
#             "geo_enabled": false,
#             "has_extended_profile": false,
#             "id": 742143,
#             "id_str": "742143",
#             "is_translation_enabled": true,
#             "is_translator": false,
#             "lang": "en",
#             "listed_count": 108988,
#             "location": "London, UK",
#             "name": "BBC News (World)",
#             "notifications": false,
#             "profile_background_color": "FFFFFF",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/742143/1485172490",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/875702138680246273/BfQLzf7G_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/875702138680246273/BfQLzf7G_normal.jpg",
#             "profile_link_color": "1F527B",
#             "profile_sidebar_border_color": "FFFFFF",
#             "profile_sidebar_fill_color": "FFFFFF",
#             "profile_text_color": "5A5A5A",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "BBCWorld",
#             "statuses_count": 279279,
#             "time_zone": null,
#             "translator_type": "none",
#             "url": "https://t.co/7NEgoMwJy3",
#             "utc_offset": null,
#             "verified": true
#         }
#     },
#     {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Fri Jun 08 19:57:33 +0000 2018",
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [
#                 {
#                     "display_url": "bbc.in/2JqhtS1",
#                     "expanded_url": "https://bbc.in/2JqhtS1",
#                     "indices": [
#                         37,
#                         60
#                     ],
#                     "url": "https://t.co/ZvjTjYB9NB"
#                 }
#             ],
#             "user_mentions": []
#         },
#         "favorite_count": 169,
#         "favorited": false,
#         "geo": null,
#         "id": 1005177028147113984,
#         "id_str": "1005177028147113984",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "en",
#         "place": null,
#         "possibly_sensitive": false,
#         "retweet_count": 82,
#         "retweeted": false,
#         "source": "<a href=\"http://www.socialflow.com\" rel=\"nofollow\">SocialFlow</a>",
#         "text": "Why Turkey\u2019s election matters to you https://t.co/ZvjTjYB9NB",
#         "truncated": false,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Thu Feb 01 07:44:29 +0000 2007",
#             "default_profile": false,
#             "default_profile_image": false,
#             "description": "News, features and analysis from the World's newsroom. Breaking news, follow @BBCBreaking. UK news, @BBCNews. Latest sports news @BBCSport",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "display_url": "bbc.com/news",
#                             "expanded_url": "http://www.bbc.com/news",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "url": "https://t.co/7NEgoMwJy3"
#                         }
#                     ]
#                 }
#             },
#             "favourites_count": 9,
#             "follow_request_sent": false,
#             "followers_count": 23513583,
#             "following": false,
#             "friends_count": 85,
#             "geo_enabled": false,
#             "has_extended_profile": false,
#             "id": 742143,
#             "id_str": "742143",
#             "is_translation_enabled": true,
#             "is_translator": false,
#             "lang": "en",
#             "listed_count": 108988,
#             "location": "London, UK",
#             "name": "BBC News (World)",
#             "notifications": false,
#             "profile_background_color": "FFFFFF",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/742143/1485172490",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/875702138680246273/BfQLzf7G_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/875702138680246273/BfQLzf7G_normal.jpg",
#             "profile_link_color": "1F527B",
#             "profile_sidebar_border_color": "FFFFFF",
#             "profile_sidebar_fill_color": "FFFFFF",
#             "profile_text_color": "5A5A5A",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "BBCWorld",
#             "statuses_count": 279279,
#             "time_zone": null,
#             "translator_type": "none",
#             "url": "https://t.co/7NEgoMwJy3",
#             "utc_offset": null,
#             "verified": true
#         }
#     },
#     {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Fri Jun 08 19:50:10 +0000 2018",
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [
#                 {
#                     "display_url": "bbc.in/2sIk4fz",
#                     "expanded_url": "https://bbc.in/2sIk4fz",
#                     "indices": [
#                         62,
#                         85
#                     ],
#                     "url": "https://t.co/q8UkWe7lxS"
#                 }
#             ],
#             "user_mentions": []
#         },
#         "favorite_count": 215,
#         "favorited": false,
#         "geo": null,
#         "id": 1005175168749236225,
#         "id_str": "1005175168749236225",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "de",
#         "place": null,
#         "possibly_sensitive": false,
#         "retweet_count": 90,
#         "retweeted": false,
#         "source": "<a href=\"http://www.socialflow.com\" rel=\"nofollow\">SocialFlow</a>",
#         "text": "Mueller charges Manafort's right-hand man Konstantin Kilimnik https://t.co/q8UkWe7lxS",
#         "truncated": false,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Thu Feb 01 07:44:29 +0000 2007",
#             "default_profile": false,
#             "default_profile_image": false,
#             "description": "News, features and analysis from the World's newsroom. Breaking news, follow @BBCBreaking. UK news, @BBCNews. Latest sports news @BBCSport",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "display_url": "bbc.com/news",
#                             "expanded_url": "http://www.bbc.com/news",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "url": "https://t.co/7NEgoMwJy3"
#                         }
#                     ]
#                 }
#             },
#             "favourites_count": 9,
#             "follow_request_sent": false,
#             "followers_count": 23513583,
#             "following": false,
#             "friends_count": 85,
#             "geo_enabled": false,
#             "has_extended_profile": false,
#             "id": 742143,
#             "id_str": "742143",
#             "is_translation_enabled": true,
#             "is_translator": false,
#             "lang": "en",
#             "listed_count": 108988,
#             "location": "London, UK",
#             "name": "BBC News (World)",
#             "notifications": false,
#             "profile_background_color": "FFFFFF",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/742143/1485172490",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/875702138680246273/BfQLzf7G_normal.jpg",
# ...
#         "id_str": "1004682687913881600",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "en",
#         "place": null,
#         "possibly_sensitive": false,
#         "retweet_count": 109,
#         "retweeted": false,
#         "source": "<a href=\"http://www.socialflow.com\" rel=\"nofollow\">SocialFlow</a>",
#         "text": "In pictures: Chile students protest against harassment https://t.co/QsSOgFHBkr",
#         "truncated": false,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Thu Feb 01 07:44:29 +0000 2007",
#             "default_profile": false,
#             "default_profile_image": false,
#             "description": "News, features and analysis from the World's newsroom. Breaking news, follow @BBCBreaking. UK news, @BBCNews. Latest sports news @BBCSport",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "display_url": "bbc.com/news",
#                             "expanded_url": "http://www.bbc.com/news",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "url": "https://t.co/7NEgoMwJy3"
#                         }
#                     ]
#                 }
#             },
#             "favourites_count": 9,
#             "follow_request_sent": false,
#             "followers_count": 23513583,
#             "following": false,
#             "friends_count": 85,
#             "geo_enabled": false,
#             "has_extended_profile": false,
#             "id": 742143,
#             "id_str": "742143",
#             "is_translation_enabled": true,
#             "is_translator": false,
#             "lang": "en",
#             "listed_count": 108988,
#             "location": "London, UK",
#             "name": "BBC News (World)",
#             "notifications": false,
#             "profile_background_color": "FFFFFF",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/742143/1485172490",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/875702138680246273/BfQLzf7G_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/875702138680246273/BfQLzf7G_normal.jpg",
#             "profile_link_color": "1F527B",
#             "profile_sidebar_border_color": "FFFFFF",
#             "profile_sidebar_fill_color": "FFFFFF",
#             "profile_text_color": "5A5A5A",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "BBCWorld",
#             "statuses_count": 279279,
#             "time_zone": null,
#             "translator_type": "none",
#             "url": "https://t.co/7NEgoMwJy3",
#             "utc_offset": null,
#             "verified": true
#         }
#     },
#     {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Thu Jun 07 11:08:27 +0000 2018",
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [
#                 {
#                     "display_url": "bbc.in/2LvBVgu",
#                     "expanded_url": "https://bbc.in/2LvBVgu",
#                     "indices": [
#                         41,
#                         64
#                     ],
#                     "url": "https://t.co/6UC2xOmq8U"
#                 }
#             ],
#             "user_mentions": []
#         },
#         "favorite_count": 152,
#         "favorited": false,
#         "geo": null,
#         "id": 1004681486220582912,
#         "id_str": "1004681486220582912",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "en",
#         "place": null,
#         "possibly_sensitive": false,
#         "retweet_count": 66,
#         "retweeted": false,
#         "source": "<a href=\"http://www.socialflow.com\" rel=\"nofollow\">SocialFlow</a>",
#         "text": "Stockholm lorry attacker jailed for life https://t.co/6UC2xOmq8U",
#         "truncated": false,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Thu Feb 01 07:44:29 +0000 2007",
#             "default_profile": false,
#             "default_profile_image": false,
#             "description": "News, features and analysis from the World's newsroom. Breaking news, follow @BBCBreaking. UK news, @BBCNews. Latest sports news @BBCSport",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "display_url": "bbc.com/news",
#                             "expanded_url": "http://www.bbc.com/news",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "url": "https://t.co/7NEgoMwJy3"
#                         }
#                     ]
#                 }
#             },
#             "favourites_count": 9,
#             "follow_request_sent": false,
#             "followers_count": 23513583,
#             "following": false,
#             "friends_count": 85,
#             "geo_enabled": false,
#             "has_extended_profile": false,
#             "id": 742143,
#             "id_str": "742143",
#             "is_translation_enabled": true,
#             "is_translator": false,
#             "lang": "en",
#             "listed_count": 108988,
#             "location": "London, UK",
#             "name": "BBC News (World)",
#             "notifications": false,
#             "profile_background_color": "FFFFFF",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/742143/1485172490",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/875702138680246273/BfQLzf7G_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/875702138680246273/BfQLzf7G_normal.jpg",
#             "profile_link_color": "1F527B",
#             "profile_sidebar_border_color": "FFFFFF",
#             "profile_sidebar_fill_color": "FFFFFF",
#             "profile_text_color": "5A5A5A",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "BBCWorld",
#             "statuses_count": 279279,
#             "time_zone": null,
#             "translator_type": "none",
#             "url": "https://t.co/7NEgoMwJy3",
#             "utc_offset": null,
#             "verified": true
#         }
#     },
#     {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Thu Jun 07 10:33:57 +0000 2018",
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [],
#             "user_mentions": [
#                 {
#                     "id": 438111039,
#                     "id_str": "438111039",
#                     "indices": [
#                         3,
#                         13
#                     ],
#                     "name": "Steve Rosenberg",
#                     "screen_name": "BBCSteveR"
#                 }
#             ]
#         },
#         "favorite_count": 0,
#         "favorited": false,
#         "geo": null,
#         "id": 1004672807119319040,
#         "id_str": "1004672807119319040",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "en",
#         "place": null,
#         "retweet_count": 95,
#         "retweeted": false,
#         "retweeted_status": {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Thu Jun 07 10:31:22 +0000 2018",
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "urls": [
#                     {
#                         "display_url": "twitter.com/i/web/status/1\u2026",
#                         "expanded_url": "https://twitter.com/i/web/status/1004672157190721537",
#                         "indices": [
#                             117,
#                             140
#                         ],
#                         "url": "https://t.co/mvCNSFWLdZ"
#                     }
#                 ],
#                 "user_mentions": []
#             },
#             "favorite_count": 155,
#             "favorited": false,
#             "geo": null,
#             "id": 1004672157190721537,
#             "id_str": "1004672157190721537",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "is_quote_status": false,
#             "lang": "en",
#             "place": null,
#             "retweet_count": 95,
#             "retweeted": false,
#             "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#             "text": "Putin\u2019s not shedding tears in public for Russian businessmen who may be having problems with the UK authorities: \u201cI\u2026 https://t.co/mvCNSFWLdZ",
#             "truncated": true,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Fri Dec 16 05:57:09 +0000 2011",
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "description": "Moscow Correspondent for BBC News",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     },
#                     "url": {
#                         "urls": [
#                             {
#                                 "display_url": "news.bbc.co.uk",
#                                 "expanded_url": "http://news.bbc.co.uk",
#                                 "indices": [
#                                     0,
#                                     22
#                                 ],
#                                 "url": "http://t.co/HGZ2nKzCrc"
#                             }
#                         ]
#                     }
#                 },
#                 "favourites_count": 286,
#                 "follow_request_sent": false,
#                 "followers_count": 58072,
#                 "following": false,
#                 "friends_count": 920,
#                 "geo_enabled": true,
#                 "has_extended_profile": false,
#                 "id": 438111039,
#                 "id_str": "438111039",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "en",
#                 "listed_count": 1855,
#                 "location": "Moscow",
#                 "name": "Steve Rosenberg",
#                 "notifications": false,
#                 "profile_background_color": "FFFFFF",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/438111039/1355528044",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/2286630588/xrtdw68jkgzoexzkf55i_normal.jpeg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/2286630588/xrtdw68jkgzoexzkf55i_normal.jpeg",
#                 "profile_link_color": "1F527B",
#                 "profile_sidebar_border_color": "AE8F9F",
#                 "profile_sidebar_fill_color": "82768C",
#                 "profile_text_color": "D78E88",
#                 "profile_use_background_image": true,
#                 "protected": false,
#                 "screen_name": "BBCSteveR",
#                 "statuses_count": 6429,
#                 "time_zone": null,
#                 "translator_type": "none",
#                 "url": "http://t.co/HGZ2nKzCrc",
#                 "utc_offset": null,
#                 "verified": true
#             }
#         },
#         "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#         "text": "RT @BBCSteveR: Putin\u2019s not shedding tears in public for Russian businessmen who may be having problems with the UK authorities: \u201cI warned o\u2026",
#         "truncated": false,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Thu Feb 01 07:44:29 +0000 2007",
#             "default_profile": false,
#             "default_profile_image": false,
#             "description": "News, features and analysis from the World's newsroom. Breaking news, follow @BBCBreaking. UK news, @BBCNews. Latest sports news @BBCSport",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "display_url": "bbc.com/news",
#                             "expanded_url": "http://www.bbc.com/news",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "url": "https://t.co/7NEgoMwJy3"
#                         }
#                     ]
#                 }
#             },
#             "favourites_count": 9,
#             "follow_request_sent": false,
#             "followers_count": 23513583,
#             "following": false,
#             "friends_count": 85,
#             "geo_enabled": false,
#             "has_extended_profile": false,
#             "id": 742143,
#             "id_str": "742143",
#             "is_translation_enabled": true,
#             "is_translator": false,
#             "lang": "en",
#             "listed_count": 108988,
#             "location": "London, UK",
#             "name": "BBC News (World)",
#             "notifications": false,
#             "profile_background_color": "FFFFFF",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/742143/1485172490",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/875702138680246273/BfQLzf7G_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/875702138680246273/BfQLzf7G_normal.jpg",
#             "profile_link_color": "1F527B",
#             "profile_sidebar_border_color": "FFFFFF",
#             "profile_sidebar_fill_color": "FFFFFF",
#             "profile_text_color": "5A5A5A",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "BBCWorld",
#             "statuses_count": 279279,
#             "time_zone": null,
#             "translator_type": "none",
#             "url": "https://t.co/7NEgoMwJy3",
#             "utc_offset": null,
#             "verified": true
#         }
#     }
# ]

# %%
# Create variable for holding the oldest tweet
oldest_tweet = None
counter = 1
for news_org in news_labels:
    # Get all tweets from home feed
    public_tweets = api.user_timeline(news_org, count=100, result_type="recent", max_id=oldest_tweet) 
    
    # Loop through all tweets
    for tweet in public_tweets:
           
        # Run Vader Analysis on each tweet
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        date = tweet['created_at'] #time created
        convert_date = datetime.strptime(date, "%a %b %d %H:%M:%S %z %Y") 
        tweets = tweet["text"]
        name = tweet["user"]["screen_name"]

       # Add each value to the appropriate list
        news_dict["Screen Name"].append(name)
        news_dict["Tweet"].append(tweets)
        news_dict["Compound Score"].append(compound)
        news_dict["Positive Score"].append(pos)
        news_dict["Negative Score"].append(neg)
        news_dict["Neutral Score"].append(neu)
        news_dict["Date"].append(convert_date) 
        news_dict["Tweets Ago"].append(counter)
        counter += 1

# %%
#Create to dataframe type
news_df = pd.DataFrame.from_dict(news_dict, orient='index')

# %%
news_tweets = news_df.transpose()
news_tweets
# Out:
#     Screen Name                                              Tweet  \
# 0           CNN  RT @OutFrontCNN: "People think, 'well, you're ...
# 1           CNN  HBO has ordered a pilot for a possible "Game o...
# 2           CNN  The only world leader who can rely on Trump is...
# 3           CNN  RT @AC360: .@andersoncooper: We have lost a fr...
# 4           CNN  Steamboat Geyser in Yellowstone National Park ...
# 5           CNN  Hilary Duff is expecting her second child http...
# 6           CNN  Organizers of a fashion show in Saudi Arabia u...
# 7           CNN  Authorities believe a woman who disappeared Fr...
# 8           CNN  A traffic stop led to a surprise reunion betwe...
# 9           CNN  Oscar-winning actress and screenwriter Emma Th...
# 10          CNN  Krill are critical to the fight against climat...
# 11          CNN  RT @CNNTonight: A CNN Special Tribute, Remembe...
# 12          CNN  Charles Krauthammer, the famed conservative co...
# 13          CNN  This US Army soldier traveled from Iraq for hi...
# 14          CNN  Bodycam video of a teenage boy's arrest has re...
# 15          CNN  You may think of the Antarctic as pristine wil...
# 16          CNN  John Lasseter will be leaving Disney at the en...
# 17          CNN  A man in Texas nearly died after the severed h...
# 18          CNN  Tonight in a special tribute, we remember and ...
# 19          CNN  The race to save the Great Barrier Reef? A cor...
# 20          CNN  Ever felt like your vacation would make a good...
# 21          CNN  Israeli soldiers on Friday killed four Palesti...
# 22          CNN  RT @AC360: Tonight, we take the full hour to r...
# 23          CNN  Anthony Bourdain was a voice for the underdog ...
# 24          CNN  RT @CNNSitRoom: "In death, as in life, Bourdai...
# 25          CNN  A total 62 people have suffered Ebola hemorrha...
# 26          CNN  This delivery man is being praised for taking ...
# 27          CNN  A Virginia jury has found former CIA case offi...
# 28          CNN  In the Maldives, a resort offers endangered se...
# 29          CNN  After President Trump's lawyers sought to keep...
# ..          ...                                                ...
# 470     FoxNews  .@POTUS on the G7 summit: "Russia should be in...
# 471     FoxNews  "I'm just really happy that he has put this ou...
# 472     FoxNews  #TheDailySpike: Wine, cheese, puppies and a to...
# 471         0.765        472
# 472             1        473
# 473         0.867        474
# 474         0.816        475
# 475         0.825        476
# 476             1        477
# 477         0.811        478
# 478             1        479
# 479             1        480
# 480             1        481
# 481             1        482
# 482         0.769        483
# 483         0.602        484
# 484             1        485
# 485         0.764        486
# 486         0.598        487
# 487         0.694        488
# 488             1        489
# 489          0.75        490
# 490         0.634        491
# 491         0.786        492
# 492         0.824        493
# 493             1        494
# 494         0.722        495
# 495         0.755        496
# 496          0.61        497
# 497         0.789        498
# 498         0.888        499
# 499         0.787        500
#
# [500 rows x 8 columns]

# %%
news_tweets.to_csv('news_analysis.csv')  # output csv

# %%
# for i in np.arange(0,len(news_labels)):
#     # Get the name of the news source, i.e., BBC 
#     news_source = news_tweets.loc[news_dfs["Screen Name"]==news_labels[i]]
#     # Now get the integers 0-100 of the tweets from the news source
#     news_source = news_source.sort_values("Tweets Ago")
#     # Build the scatter plot
#     plt.scatter(np.arange(len(news_source["Compound Score"])), 
#             # Set the Compound Score to a color and add the news source to the label. 
#             news_source["Compound Score"], color = colors[i],
#             edgecolor="black", linewidths=1, marker="o",
#             alpha=0.8,label = news_labels[i])

colors = ['red', 'blue','lightblue', 'green', 'yellow']

# Create plot
x_vals = news_tweets["Tweets Ago"]
y_vals = news_tweets["Compound Score"]
plt.scatter(x_vals,
         y_vals, marker="o", color = colors,
         alpha=0.8)

# # Incorporate the other graph properties
now = datetime.now()
now = now.strftime("%Y-%m-%d %H:%M")
plt.title(f"Sentiment Analysis of Media Tweets ({now})")
# plt.xlim([x_vals.max(),x_vals.min()]) #Bonus
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.savefig('tweets_scatter.png', bbox_inches = 'tight')
plt.show()

# %%
news_tweets.dtypes
# Out:
# Screen Name       object
# Tweet             object
# Date              object
# Compound Score    object
# Positive Score    object
# Negative Score    object
# Neutral Score     object
# Tweets Ago        object
# dtype: object

# %%
news_tweets["Compound Score"] = news_tweets["Compound Score"].astype(str).astype(float)

# %%
# group by SN and find average of each group# group b 
scores_by_org = news_tweets.groupby('Screen Name')['Compound Score'].mean()
print(scores_by_org)

# bar chart of mean scores labels
plt.title('Average Sentiment of the Last 100 Tweets of Popular News Outlets \n Samples taken from %s' % (date))
plt.xlabel('News Network')
plt.ylabel('Average Polarity Score')

# list from group by network
xlabels = scores_by_org.index
# location of each bar
xvals = np.arange(len(scores_by_org))
y_min = -1.0
y_max = 0.4
count = 0 # for x coord location of value label

#create each value label
for score in scores_by_org: 
    if score < 0: #for neg scores, put label under
        height = score - .01
    else: # for + scores, put label above
        height = score + .01
    plt.text(count, height, str(round(score, 2)), ha = 'center', va = 'center')
    count += 1
plt.bar(xvals, 
        scores_by_org, 
        color = colors, # sets colors from news_labels dict from xlabel list
        tick_label = news_labels)
plt.savefig('average_scores.png')
plt.show()
# Out:
# Screen Name
# BBCWorld   -0.060917
# CBSNews    -0.062632
# CNN         0.029261
# FoxNews     0.015667
# nytimes    -0.057477
# Name: Compound Score, dtype: float64
